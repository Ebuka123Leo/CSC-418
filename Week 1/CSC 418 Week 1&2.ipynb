# %%
# import the OpenCV library
import cv2

#path
path = 'img/City11.jpeg'

#reading the image with imread() function
img = cv2.imread(path)

# Window name in which image is displayed
window_name = 'Display image'

#Display image
cv2.imshow(window_name, img)

# Hold the window
cv2.waitKey(0)

# Remove/delete cretaed GUI window from screen and memory
cv2.destroyAllWindows()

# %%
# importing the opencv library

import cv2 

#path

path = 'img/city11.jpeg'

#reading an image in greyscale mode

img = cv2.imread(path, 0)

# Window name in which image is displayed
Window_name = 'City logo'

# display image
cv2.imshow (window_name, img)

# Hold the window
cv2.waitKey(0)

# Remove/delete cretaed GUI window from screen and memory
cv2.destroyAllWindows()

# %%
#python program explaining cv2.imwrite() method

#import the opencv library
import cv2

#importing os module
import os

#import path
image_path = r'C:\Users\HP\Desktop\CSC 418 REPOSITORY\Week 1\img\City11.jpeg'

#image directory
directory =  r'C:\Users\HP\Desktop\CSC 418 REPOSITORY\Week 1\img'

#using cv2.imread ()method to read the image
img = cv2.imread (image_path, 0)

#change the current directory to specified directory
os.chdir(directory)

print("Before saving image:")
print(os.listdir(directory))

#filename
filename = 'grayImage.jpg'

#using cv2.imwrite() method to save the image
cv2.imwrite(filename, img)

print ("After saving image:")
print (os.listdir(directory))

print ("successfully saved")
# Out:
# Before saving image:
# ['City11.jpeg']
# After saving image:
# ['City11.jpeg', 'grayImage.jpg']
# successfully saved

# %%
# WEEK 2

import cv2

# Read the image
image = cv2.imread('img/City11.jpeg')

# The split method separates color spaces
B, G, R = cv2.split(image)

# Corresponding channels are separated
cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# A program to illustrate arithmetic operation of addition

# Organizing imports
import cv2

# Path to input images
image1 = cv2.imread('img/City11.jpeg')
image2 = cv2.imread('img/Doku.jpeg')

# Resize images
image1 = cv2.resize(image1, (500, 400))
image2 = cv2.resize(image2, (500, 400))

# cv2.addWeighted with applied parameters
addImage = cv2.addWeighted(image1, 0.5, image2, 0.6, 0)

# Uncomment the following line to perform subtraction instead of addition
# sub = cv2.subtract(image1, image2)

# Window showing output image
cv2.imshow('Weighted Image', addImage)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xFF == 27:
    cv2.destroyAllWindows()

# %%
# Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('img/City11.jpeg')

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Adjust the brightness and contrast
brightness = 5
contrast = 1.5
image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness)

# Save the image
cv2.imwrite('img/contrast_image.jpg', image2)

# Plot the contrast image
plt.subplot(1, 2, 2)
plt.title("Brightness & Contrast")
plt.imshow(image2)

# Show the images
plt.show()

# %%
# !pip install matplotlib

# %%
# Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('img/City11.jpeg')

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Create the sharpening kernel
kernel = np.array([[0, -1, 0], 
                   [-1, 5, -1], 
                   [0, -1, 0]])

# Sharpen the image
sharpened_image = cv2.filter2D(image, -1, kernel)

# Save the image
cv2.imwrite('img/sharpened_image.jpg', sharpened_image)

# Plot the sharpened image
plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)

# Show both images
plt.show()

# %%
# Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('img/City11.jpeg')

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Remove noise using a median filter
filtered_image = cv2.medianBlur(image, 15)

# Save the filtered image
cv2.imwrite('img/Median-Blur.jpg', filtered_image)

# Plot the blurred image
plt.subplot(1, 2, 2)
plt.title("Median Blur")
plt.imshow(filtered_image)

# Show both images
plt.show()

# %%
# Import the necessary libraries
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('img/City11.jpeg')

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Scale the image by a factor of 2 along both axes
scaled_image = cv2.resize(image, None, fx=2, fy=2)

# Save the scaled image
cv2.imwrite('img/Scaled.jpg', scaled_image)

# Plot the scaled image
plt.subplot(1, 2, 2)
plt.title("Scaled")
plt.imshow(scaled_image)

# Show both images
plt.show()

# %%
# Import the necessary libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the image
image = cv2.imread('img/City11.jpeg')

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Inverse by subtracting from 255
inverse_image = 255 - image

# Save the inverted image
cv2.imwrite('img/inverse_image.jpg', inverse_image)

# Plot the inverted image
plt.subplot(1, 2, 2)
plt.title("Inverse color")
plt.imshow(inverse_image)

# Show both images
plt.show()
