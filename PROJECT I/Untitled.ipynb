# %%
import cv2
import matplotlib.pyplot as plt

adaora_image = cv2.imread("img/Adaora.jpg")
Chris_image = cv2.imread("img/Chris.jpg")
Darlington_image = cv2.imread("img/Darlington.jpg")
Enase_image = cv2.imread("img/Enase.jpg")
Ikechukwu_image = cv2.imread("img/Ikechukwu.jpg")
Nneka_image = cv2.imread("img/Nneka.jpg")
Obiaya_image = cv2.imread("img/Obiaya.jpg")
Peter_image = cv2.imread("img/Peter.jpg")
Sola_image = cv2.imread("img/Sola.jpg")



pathdictionary = {
    "Adaora" : adaora_image,
    "Chris" : Chris_image,
    "Darlington": Darlington_image,
    "Enase" : Enase_image,
    "Ikechukwu" : Ikechukwu_image,
    "Nneka" : Nneka_image,
    "Obiaya" : Obiaya_image,
    "Peter" : Peter_image,
    "Sola" : Sola_image

}


lyst=[]
for c in pathdictionary.keys():
    lyst.append(c)
print(lyst)


Surname_dict = {}

Last_name = ["Onaga", "Ogbechie", "Agholor", "Okonedo", "Ogbuike", "Okekearu", " Ikechukwu", "Bamkole", "Oni"]

for s in range(len(lyst)):
    Surname_dict[lyst[s]] = Last_name[s]



#print(Surname_dict)


password_key = {}


for s in range (len(lyst)):
    password_key[lyst[s]] = len(Surname_dict[lyst[s]])
#print(f"Password test {password_key}")

inp = input("Enter your name:    ")

if inp not in lyst:
    print("Name is non-existent")
else:
    pass_inp = int( input("Input your password "))
    if password_key[inp]==pass_inp:
        cv2.imshow(inp,pathdictionary[inp])
        cv2.waitKey(0)
        cv2.destroyAllWindows()
    else:
        print("Error")
# Out:
# ['Adaora', 'Chris', 'Darlington', 'Enase', 'Ikechukwu', 'Nneka', 'Obiaya', 'Peter', 'Sola']
# Enter your name:     Enase
# Input your password  7

# %%
mydict={}
mydict["Daniel"]="Obere"
mydict["Daniel"]
print(len(mydict))
# Out:
# 1

# %%
import cv2
import matplotlib.pyplot as plt

Ada_image = cv2.imread("Ada.jpeg")
Bimpe_image = cv2.imread("Bimpe.jpeg")
Chima_image = cv2.imread("Chima.jpeg")
Clement_image = cv2.imread("Clement.jpeg")
Dumebi_image = cv2.imread("Dumebi.jpeg")
Love_image = cv2.imread("Love.jpeg")
Miracle_image = cv2.imread("Miracle.jpeg")
Miriam_image = cv2.imread("Miriam.jpeg")
Oyinda_image = cv2.imread("Oyinda.jpeg")
Tomi_image = cv2.imread("Tomi.jpeg")


List = ["Ada", "Bimpe", "Chima", "Clement", "Dumebi", "Love", "Miracle", "Miriam", "Oyinda", "Tomi"]

picture_key = {
    "Ada": Ada_image,
    "Bimpe": Bimpe_image,
    "Chima": Chima_image,
    "Clement":Clement_image,
    "Dumebi": Dumebi_image,
    "Love": Love_image,
    "Miracle":Miracle_image,
    "Miriam": Miriam_image,
    "Oyinda": Oyinda_image,
    "Tomi": Tomi_image

}

random_number=21120612481


    
matric_key ={}



for z in range (len(picture_key)):
    matric_key[List[z]] = random_number
    random_number+=1
print(matric_key)

    
    

def Inversetransform(imagex):
    image = cv2.imread(imagex)

# Plot the original image
    plt.subplot(1, 2, 1)
    plt.title("Original")
    plt.imshow(image)

# Inverse by subtracting from 255
    -inverse_image = 255 - image

# Save the inverted image
    cv2.imwrite('img/inverse_image.jpg', inverse_image)

# Plot the inverted image
    plt.subplot(1, 2, 2)
    plt.title("Inverse color")
    plt.imshow(inverse_image)

# Show both images
    plt.show()
    



def imagescaling(imagex)
    image = cv2.imread(imagex)

# Plot the original image
    plt.subplot(1, 2, 1)
    plt.title("Original")
    plt.imshow(image)

# Scale the image by a factor of 2 along both axes
    scaled_image = cv2.resize(image, None, fx=2, fy=2)

# Save the scaled image
    cv2.imwrite('img/Scaled.jpg', scaled_image)

# Plot the scaled image
    plt.subplot(1, 2, 2)
    plt.title("Scaled")
    plt.imshow(scaled_image)

# Show both images
    plt.show()

def removing_noise(imagex)
    image = cv2.imread(imagex)

# Plot the original image
    plt.subplot(1, 2, 1)
    plt.title("Original")
    plt.imshow(image)

# Remove noise using a median filter
    filtered_image = cv2.medianBlur(image, 15)

# Save the filtered image
    cv2.imwrite('img/Median-Blur.jpg', filtered_image)

# Plot the blurred image
    plt.subplot(1, 2, 2)
    plt.title("Median Blur")
    plt.imshow(filtered_image)

# Show both images
    plt.show()


def Adjusting_brightness(imagex)
    image = cv2.imread(imagex)

# Plot the original image
    plt.subplot(1, 2, 1)
    plt.title("Original")
    plt.imshow(image)

# Adjust the brightness and contrast
    brightness = 5
    contrast = 1.5
    image2 = cv2.addWeighted(image, contrast, np.zeros(image.shape, image.dtype), 0, brightness)

# Save the image
    cv2.imwrite('img/contrast_image.jpg', image2)

# Plot the contrast image
    plt.subplot(1, 2, 2)
    plt.title("Brightness & Contrast")
    plt.imshow(image2)

# Show the images
    plt.show()


def Arithmetic_operations(imagex,imagey)
    image1 = cv2.imread(imagex)
    image2 = cv2.imread(imagey)

# Resize images
    image1 = cv2.resize(image1, (500, 400))
    image2 = cv2.resize(image2, (500, 400))

# cv2.addWeighted with applied parameters
    addImage = cv2.addWeighted(image1, 0.5, image2, 0.6, 0)

# Uncomment the following line to perform subtraction instead of addition
# sub = cv2.subtract(image1, image2)

# Window showing output image
    cv2.imshow('Weighted Image', addImage)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xFF == 27:
    cv2.destroyAllWindows()


def sharpening(imagex)
    image = cv2.imread(imagex)

# Plot the original image
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

# Create the sharpening kernel
kernel = np.array([[0, -1, 0], 
                   [-1, 5, -1], 
                   [0, -1, 0]])

# Sharpen the image
sharpened_image = cv2.filter2D(image, -1, kernel)

# Save the image
cv2.imwrite('img/sharpened_image.jpg', sharpened_image)

# Plot the sharpened image
plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)

# Show both images
plt.show()



input_name = input("Enter your name: ")

if input_name not in List:
    print("Name does not exist")
else:
    matric_no = input("Input your Matric Number")
    if matric_key[input_name]== matric_no:
        List= ["Removing noise, Inverse transform, inverse scaling,

#for z in range (len(list))
# Out:
# {'Ada': 21120612481, 'Bimpe': 21120612482, 'Chima': 21120612483, 'Clement': 21120612484, 'Dumebi': 21120612485, 'Love': 21120612486, 'Miracle': 21120612487, 'Miriam': 21120612488, 'Oyinda': 21120612489, 'Tomi': 21120612490}
